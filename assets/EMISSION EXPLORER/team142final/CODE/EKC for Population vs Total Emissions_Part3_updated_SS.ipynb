# %%
import matplotlib.pyplot as plt

# %%
# Data for WECC region- with labels of year
WECC_population = [57406, 58487, 59557, 60598, 61599,
              62568, 63429, 64216, 65033, 65873, 66768, 67600, 68489, 69295, 70025,
              70689, 71358, 72028, 72781, 73589, 74399, 75101, 75682, 76151, 76468, 76407]


WECC_CO2_emissions = [ 863.283769,873.770382, 913.47735, 926.438527, 960.554793, 965.728115, 944.971812,
                 949.227147, 989.80393, 995.466351, 999.41592, 1022.749028, 993.304647,
                 949.933111, 942.072403, 909.892523, 907.050554, 932.30943, 917.556682,
                 918.231406, 908.119082, 915.317415, 923.649034, 932.327892, 809.848032,
                 855.788992]

years = list(range(1996, 2022))


plt.figure(figsize=(10, 6))
plt.plot(WECC_population, WECC_CO2_emissions, color='blue', marker='o', linestyle='-')

for i, year in enumerate(years):
    plt.text(WECC_population[i], WECC_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for WECC')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()

# %%
# Data for TX region- with labels of year
TX_population = [19340, 19740, 20158, 20558, 20944,
                 21320, 21690, 22031, 22394, 22778, 23360, 23832, 24309, 24802, 25242,
                 25646, 26084, 26480, 26963, 27469, 27914, 28291, 28625, 28987, 29232, 29559]

TX_CO2_emissions = [ 635.695744,649.760705, 656.476605, 646.856348, 673.038576, 666.89956, 678.25234,
                    671.21972, 670.653018, 645.021576, 648.38216, 646.192763, 623.648595,
                    590.457028, 615.543957, 635.041655, 627.109709, 657.830179, 661.990468,
                    655.258602, 656.870948, 665.085545, 684.814849, 683.41525, 624.681653, 663.458164]

years = list(range(1996, 2022))

plt.figure(figsize=(10, 6))
plt.plot(TX_population, TX_CO2_emissions, color='red', marker='o', linestyle='-')

for i, year in enumerate(years):
    plt.text(TX_population[i], TX_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for TX')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()

# %%
# Data for SERC region
SERC_population = [81323, 82503, 83605, 84678, 85732,
                   86646, 87547, 88414, 89541, 90728, 91726, 92874, 93888, 94727, 95558,
                   96240, 96974, 97648, 98361, 99153, 100013, 100777, 101412, 102010, 102566, 103018]

SERC_CO2_emissions = [1754.431905,1786.615913, 1788.146349, 1818.208381, 1888.281417, 1844.857217, 1859.561108,
                      1883.935022, 1940.034654, 1961.153402, 1955.316086, 1976.96513, 1895.232947,
                      1751.523649, 1863.804991, 1797.88091, 1700.033645, 1711.696772, 1743.297973,
                      1687.967067, 1672.817584, 1648.286561, 1688.010765, 1625.141536, 1455.68367, 1560.518891]


years = list(range(1996, 2022))

plt.figure(figsize=(10, 6))
plt.plot(SERC_population, SERC_CO2_emissions, color='green', marker='o', linestyle='-')


for i, year in enumerate(years):
    plt.text(SERC_population[i], SERC_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for SERC')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()

# %%
# Data for RFC region
RFC_population = [ 55526, 55783, 56040, 56313, 56599,
                  56845, 57088, 57344, 57548, 57719, 57908, 58056, 58199, 58375, 58566,
                  58747, 58900, 59060, 59202, 59278, 59371, 59490, 59586, 59638, 60550, 60531]

RFC_CO2_emissions = [1276.246964,1278.710682, 1270.342751, 1289.988318, 1319.316544, 1267.971329, 1295.696709,
                     1315.540359, 1316.867121, 1333.923677, 1292.481307, 1314.63175, 1276.710305,
                     1146.933685, 1183.015508, 1143.89523, 1076.29791, 1114.853077, 1134.634998,
                     1070.607577, 1037.435702, 1013.544469, 1054.87773, 1010.487085, 893.973877, 967.348212]


years = list(range(1996, 2022))

plt.figure(figsize=(10, 6))
plt.plot(RFC_population, RFC_CO2_emissions, color='darkorange',  marker='o', linestyle='-')

for i, year in enumerate(years):
    plt.text(RFC_population[i], RFC_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for RFC')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()

# %%
# Data for NPCC region
NPCC_population = [32144, 32298, 32489, 32720, 32952,
                   33125, 33260, 33359, 33379, 33349, 33350, 33411, 33553, 33712, 33870,
                   34032, 34167, 34276, 34362, 34392, 34401, 34401, 34384, 34313, 35183, 34979]

NPCC_CO2_emissions = [372.828261,387.864794, 381.905077, 384.227528, 395.553405, 389.775655, 384.807907,
                      403.89681, 407.133283, 402.130341, 369.079526, 377.550355, 358.703083,
                      333.262095, 345.62527, 329.604168, 310.940082, 316.884172, 324.156997,
                      326.328853, 313.809201, 309.096391, 322.508635, 313.748486, 270.678795, 292.65165]


years = list(range(1996, 2022))


plt.figure(figsize=(10, 6))
plt.plot(NPCC_population, NPCC_CO2_emissions, color='purple', marker='o', linestyle='-')

for i, year in enumerate(years):
    plt.text(NPCC_population[i], NPCC_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for NPCC')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()

# %%
# Data for MRO region
MRO_population = [21844, 22008, 22170, 22338, 22497,
                  22608, 22727, 22845, 22979, 23106, 23287, 23463, 23635, 23819, 23992,
                  24130, 24271, 24427, 24567, 24695, 24800, 24899, 24989, 25083, 25331, 25356]

MRO_CO2_emissions = [542.568853,540.703795, 541.841368, 550.639127, 568.542163, 560.77951, 569.19255,
                     578.489629, 572.199949, 582.500555, 574.616733, 592.434442, 597.594838,
                     567.484068, 577.567654, 575.874944, 551.712242, 573.321724, 582.15099,
                     554.183771, 537.504245, 538.175102, 566.907991, 539.796633, 488.951956, 515.249033]

years = list(range(1996, 2022))

plt.figure(figsize=(10, 6))
plt.plot(MRO_population, MRO_CO2_emissions, color='magenta', marker='o', linestyle='-')

for i, year in enumerate(years):
    plt.text(MRO_population[i], MRO_CO2_emissions[i], str(year), fontsize=8, color='black')

plt.title('Population vs. Total CO2 Emissions (1996-2021) for MRO')
plt.xlabel('Population (in thousands)')
plt.ylabel('Total CO2 Emissions(in million metric tons)')
plt.grid(True)
plt.show()
